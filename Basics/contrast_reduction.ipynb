# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import PIL as pillow

# %%
image = cv2.imread('panda.jpg')
plt.imshow(image)

# %%
image2 = cv2.bitwise_not(image)
plt.imshow(image2)
cv2.imwrite('panda_2.jpg', image2)
# Out:
# True

# %%
from PIL import Image
from numpy import array
img = Image.open('panda.jpg')
ar = array(img)
ar
# Out:
# array([[[158, 182, 194],
#         [164, 187, 201],
#         [166, 190, 202],
#         ...,
#         [ 48,  71,  27],
#         [143, 165, 152],
#         [163, 184, 189]],
#
#        [[159, 183, 193],
#         [162, 185, 199],
#         [165, 188, 202],
#         ...,
#         [ 21,  42,   9],
#         [110, 131, 126],
#         [161, 180, 194]],
#
#        [[161, 186, 193],
#         [159, 182, 196],
#         [162, 185, 203],
#         ...,
#         [ 17,  36,  14],
#         [ 85, 105, 103],
#         [166, 185, 199]],
#
#        ...,
#
#        [[107, 135,  16],
#         [ 93, 115,   7],
#         [ 93, 114,   0],
#         ...,
#         [114, 139,   9],
#         [130, 153,   0],
#         [138, 160,   0]],
#
#        [[100, 127,  10],
#         [ 89, 109,  10],
#         [ 86, 104,   0],
#         ...,
#         [114, 137,   7],
#         [126, 146,   0],
#         [131, 152,   0]],
#
#        [[ 88, 115,   0],
#         [ 86, 103,   9],
#         [ 79,  96,   0],
#         ...,
#         [114, 135,   4],
#         [121, 140,   0],
#         [123, 146,   0]]], dtype=uint8)

# %%
img2 = Image.open('panda_2.jpg')
ar2 = array(img2)
ar2
# Out:
# array([[[ 96,  72,  60],
#         [ 91,  67,  57],
#         [ 89,  64,  57],
#         ...,
#         [206, 189, 225],
#         [111,  88, 106],
#         [ 89,  66,  72]],
#
#        [[ 97,  73,  61],
#         [ 93,  69,  57],
#         [ 89,  64,  57],
#         ...,
#         [233, 214, 246],
#         [145, 123, 136],
#         [ 95,  73,  76]],
#
#        [[ 95,  72,  58],
#         [ 96,  72,  60],
#         [ 93,  68,  61],
#         ...,
#         [237, 219, 241],
#         [169, 148, 155],
#         [ 91,  67,  67]],
#
#        ...,
#
#        [[147, 123, 235],
#         [162, 139, 253],
#         [159, 138, 255],
#         ...,
#         [142, 115, 246],
#         [126, 104, 251],
#         [116,  97, 251]],
#
#        [[156, 130, 240],
#         [168, 144, 254],
#         [170, 147, 255],
#         ...,
#         [144, 117, 248],
#         [132, 110, 255],
#         [124, 105, 255]],
#
#        [[164, 138, 247],
#         [173, 150, 255],
#         [177, 155, 255],
#         ...,
#         [144, 117, 248],
#         [135, 113, 255],
#         [128, 109, 255]]], dtype=uint8)
